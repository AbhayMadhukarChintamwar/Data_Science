# %%
import matplotlib.pyplot as plt
x = [10,30,40,50]
area = [10,30,40,50]
plt.stackplot(x,area)
print(plt.show())
# plt.show()
# Out:
# None

# %%
import matplotlib.pyplot as plt
x = [10,30,40,50]
area = [30,20,10,60]
plt.stackplot(x,area)
print(plt.show())
# plt.show()
# Out:
# None

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area = [2,5,3,4,1]
plt.stackplot(x,area)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,2,3,5]
plt.stackplot(x,area1,area2, area3)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,2,3,5]
l = ['area1','area2','area3']
plt.stackplot(x,area1,area2, area3, labels=l)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,2,3,5]
l = ['area1','area2','area3']
plt.stackplot(x,area1,area2, area3, labels=l)
plt.legend(loc=1)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,2,3,5]
l = ['area1','area2','area3']
plt.stackplot(x,area1,area2, area3, labels=l)
plt.legend(loc=2)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,2,3,5]
l = ['area1','area2','area3']
plt.stackplot(x,area1,area2, area3, labels=l)
plt.legend(loc=3)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,2,3,5]
l = ['area1','area2','area3']
plt.stackplot(x,area1,area2, area3, labels=l)
plt.legend(loc=4)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,2,3,5]
l = ['area1','area2','area3']
plt.stackplot(x,area1,area2, area3, labels=l)
plt.legend(loc=1)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,2,3,5]
l = ['area1','area2','area3']
c =['r','aqua','y']
plt.stackplot(x,area1,area2, area3, labels=l, colors=c)
plt.legend(loc=1)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,2,3,5]
l = ['area1','area2','area3']
c =['r','aqua','y']
plt.stackplot(x,area1,area2, area3, labels=l, colors=c, baseline='sym')
plt.legend(loc=1)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,2,3,5]
l = ['area1','area2','area3']
c =['r','aqua','y']
plt.stackplot(x,area1,area2, area3, labels=l, colors=c, baseline='zero')
plt.legend(loc=1)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,2,3,5]
l = ['area1','area2','area3']
c =['r','aqua','y']
plt.stackplot(x,area1,area2, area3, labels=l, colors=c, baseline='wiggle')
plt.legend(loc=1)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,2,3,5]
l = ['area1','area2','area3']
c =['r','aqua','y']
plt.stackplot(x,area1,area2, area3, labels=l, colors=c, baseline='wiggle')
plt.legend(loc=1)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,2,3,5]
l = ['area1','area2','area3']
c =['r','aqua','y']
plt.stackplot(x,area1,area2, area3, labels=l, colors=c, baseline='zero')
plt.legend(loc=1)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,2,3,5]
l = ['area1','area2','area3']
c =['r','aqua','y']
plt.stackplot(x,area1,area2, area3, labels=l, colors=c, baseline='zero')
plt.title('Area Stack Graph')
plt.legend(loc=1)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,2,3,5]
l = ['area1','area2','area3']
c =['r','aqua','y']
plt.stackplot(x,area1,area2, area3, labels=l, colors=c, baseline='zero')
plt.title('Area Stack Graph')
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.legend(loc=1)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,2,3,5]
l = ['area1','area2','area3']
c =['r','aqua','y']
plt.stackplot(x,area1,area2, area3, labels=l, colors=c, baseline='zero')
plt.title('Area Stack Graph', fontsize = 20)
plt.xlabel('x - axis' , fontsize = 15)
plt.ylabel('y - axis' , fontsize = 15)
plt.legend(loc=1)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area1 = [2,5,3,4,1]
area2 = [1,2,3,4,2]
area3 = [4,1,2,3,5]
l = ['area1','area2','area3']
c =['r','aqua','y']
plt.stackplot(x,area1,area2, area3, labels=l, colors=c, baseline='zero')
plt.grid()
plt.title('Area Stack Graph', fontsize = 20)
plt.xlabel('x - axis' , fontsize = 15)
plt.ylabel('y - axis' , fontsize = 15)
plt.legend(loc=1)
plt.show()
