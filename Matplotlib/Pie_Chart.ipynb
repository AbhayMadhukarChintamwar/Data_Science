# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
plt.pie(x)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
plt.pie(x, labels = y)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
ex = [0.0,0.1,0.0,0.0]
plt.pie(x, labels = y, explode = ex)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
c = ['magenta', 'aqua','red','blue']
plt.pie(x, labels = y, colors=c )
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
plt.pie(x, labels = y, autopct='%0.1f%%' )
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
c = ['magenta', 'aqua','red','blue']
plt.pie(x, labels = y, colors=c, autopct='%0.1f%%' )
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
c = ['magenta', 'aqua','red','blue']
plt.pie(x, labels = y, colors=c, autopct='%0.1f%%',shadow=True )
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
c = ['magenta', 'aqua','red','blue']
plt.pie(x, labels = y, colors=c, autopct='%0.1f%%',shadow=True , radius=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
c = ['magenta', 'aqua','red','blue']
plt.pie(x, labels = y, colors=c, autopct='%0.1f%%',shadow=True , radius=1)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
c = ['magenta', 'aqua','red','blue']
plt.pie(x, labels = y, colors=c, autopct='%0.1f%%',labeldistance=1.2)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
c = ['magenta', 'aqua','red','blue']
plt.pie(x, labels = y, colors=c, autopct='%0.1f%%',labeldistance=1.2, startangle=90)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
c = ['magenta', 'aqua','red','blue']
plt.pie(x, labels = y, colors=c, autopct='%0.1f%%',labeldistance=1.2,textprops={'fontsize':15})
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
c = ['magenta', 'aqua','red','blue']
plt.pie(x, labels = y, colors=c, autopct='%0.1f%%',labeldistance=1.2, counterclock=False)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
ex = [0.0,0.2,0.0,0.0]
plt.pie(x, labels = y, explode = ex)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
ex = [0.0,0.2,0.0,0.0]
plt.pie(x, labels = y, explode = ex, shadow=True, wedgeprops = {'linewidth':4})
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
ex = [0.0,0.2,0.0,0.0]
plt.pie(x, labels = y, explode = ex, shadow=True, wedgeprops = {'linewidth':4,'edgecolor':'yellow'})
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
ex = [0.0,0.2,0.0,0.0]
plt.pie(x, labels = y, explode = ex, shadow=True, wedgeprops = {'linewidth':4}, rotatelabels=True)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']
# ex = [0.0,0.2,0.0,0.0]
plt.pie(x, labels = y,  shadow=True,  rotatelabels=True)
plt.title('Subject Analysis')
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = ['Python','Java','Machine Learning','Data Science']

plt.pie(x, labels = y,  shadow=True,  rotatelabels=True)
plt.title('Subject Analysis')
plt.legend(loc = 10)
plt.show()
