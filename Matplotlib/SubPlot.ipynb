# %%
import matplotlib.pyplot as plt
x =[1,2,3,4,5]
y =[1,2,3,4,5]
plt.plot(x,y,color='r')
x1 =[1,2,3,4,5]
y1 = [2,3,5,4,1]
plt.step(x1,y1)
x2 = [10,20,30,40]
plt.pie(x2)
x3 = ['a','b','c','d']
y3 =[2,3,4,5]
plt.bar(x3,y3)
# plt.show()
print(plt.show())
# Out:
# None

# %%
import matplotlib.pyplot as plt
x =[1,2,3,4,5]
y =[1,2,3,4,5]
plt.subplot(2,2,1)
plt.plot(x,y, color ='r')

x1 =[1,2,3,4,5]
y1 = [1,2,3,4,5]
plt.subplot(2,2,2)
plt.step(x1,y1)

x2 = [10,20,30,40]
plt.subplot(2,2,3)
plt.pie(x2)

x3 = ['a','b','c','d']
y3 =[2,3,4,5]
plt.subplot(2,2,4)
plt.bar(x3,y3)
plt.show()

# %%
import matplotlib.pyplot as plt
x =[1,2,3,4,5]
y =[1,2,3,4,5]
plt.subplot(3,3,1)
plt.plot(x,y, color ='r')

x1 =[1,2,3,4,5]
y1 = [1,2,3,4,5]
plt.subplot(3,3,2)
plt.step(x1,y1)

x2 = [10,20,30,40]
plt.subplot(3,3,3)
plt.pie(x2)

x3 = ['a','b','c','d']
y3 =[2,3,4,5]
plt.subplot(3,3,4)
plt.bar(x3,y3)
plt.show()

# %%
import matplotlib.pyplot as plt
x =[1,2,3,4,5]
y =[1,2,3,4,5]
plt.subplot(4,4,1)
plt.plot(x,y, color ='r')

x1 =[1,2,3,4,5]
y1 = [1,2,3,4,5]
plt.subplot(4,4,2)
plt.step(x1,y1)

x2 = [10,20,30,40]
plt.subplot(4,4,3)
plt.pie(x2)

x3 = ['a','b','c','d']
y3 =[2,3,4,5]
plt.subplot(4,4,4)
plt.bar(x3,y3)
plt.show()

# %% [markdown]
# savefig

# %%
import matplotlib.pyplot as plt
x =[1,2,3,4,5]
y =[1,2,3,4,5]
plt.subplot(2,2,1)
plt.plot(x,y, color ='r')

x1 =[1,2,3,4,5]
y1 = [1,2,3,4,5]
plt.subplot(2,2,2)
plt.step(x1,y1)

x2 = [10,20,30,40]
plt.subplot(2,2,3)
plt.pie(x2)

x3 = ['a','b','c','d']
y3 =[2,3,4,5]
plt.subplot(2,2,4)
plt.bar(x3,y3)

plt.savefig('Sub Plot 1')
plt.show()
