# %% [markdown]
# Exploratory Data Analysis

# %%
import pandas as pd

# %%
# Input variables (based on physicochemical tests):
# 1- fixed acidity
# 2- volatile acidity
# 3- citric acid
# 4- residual sugar
# 5 - chlorides
# 6- free sulfur dioxide
# 7- total sulfur dioxide
# 8- density
# 9- pH
# 10- sulphates
# 11- alcohol
# Output-  Varivale (Based on sensory data):
# 12- quality (score between 0 to 10)

# %%
df =pd.read_csv('1.0 - winequality-red.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           8.49             0.378        0.262           10.25      0.119
# 1          15.41             0.913        0.247           12.05      0.163
# 2          12.78             1.409        0.906            4.13      0.154
# 3          11.18             1.198        0.250            9.56      0.039
# 4           5.87             1.310        0.272            8.79      0.038
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   51                   175  0.99517  3.77       1.07
# 1                   71                   172  0.99241  2.91       0.96
# 2                   48                   193  0.99845  3.56       1.97
# 3                   19                   174  1.00416  3.90       0.96
# 4                    6                   294  0.99006  3.05       0.44
#
#    alcohol  quality
# 0    13.48       10
# 1    13.22        1
# 2    12.23        8
# 3    12.80        8
# 4     8.13        2

# %%
# summary of dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1000 non-null   float64
#  1   volatile acidity      1000 non-null   float64
#  2   citric acid           1000 non-null   float64
#  3   residual sugar        1000 non-null   float64
#  4   chlorides             1000 non-null   float64
#  5   free sulfur dioxide   1000 non-null   int64
#  6   total sulfur dioxide  1000 non-null   int64
#  7   density               1000 non-null   float64
#  8   pH                    1000 non-null   float64
#  9   sulphates             1000 non-null   float64
#  10  alcohol               1000 non-null   float64
#  11  quality               1000 non-null   int64
# dtypes: float64(9), int64(3)
# memory usage: 93.9 KB

# %%
#  descriptive summary of the dataset
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1000.000000       1000.000000  1000.000000     1000.000000
# mean        9.883050          0.860519     0.502413        7.610360
# std         3.505711          0.438287     0.290670        4.153946
# min         4.060000          0.105000     0.000000        0.510000
# 25%         6.835000          0.461750     0.261500        4.007500
# 50%         9.965000          0.878500     0.501000        7.525000
# 75%        12.935000          1.240250     0.759000       11.192500
# max        16.000000          1.599000     0.998000       14.990000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1000.000000          1000.000000           1000.000000  1000.000000
# mean      0.103880            38.108000            159.726000     0.997354
# std       0.054499            21.589777             83.872973     0.004311
# min       0.010000             1.000000              6.000000     0.990000
# 25%       0.056750            19.000000             92.000000     0.993620
# 50%       0.104000            39.000000            161.000000     0.997260
# 75%       0.150250            57.000000            231.000000     1.000952
# max       0.200000            74.000000            299.000000     1.004990
#
#                 pH   sulphates      alcohol      quality
# count  1000.000000  1000.00000  1000.000000  1000.000000
# mean      3.378080     1.13308    11.561650     4.850000
# std       0.340867     0.47419     2.029173     3.141555
# min       2.800000     0.30000     8.000000     0.000000
# 25%       3.080000     0.74750     9.770000     2.000000
# 50%       3.355000     1.13000    11.585000     5.000000
# 75%       3.660000     1.53000    13.332500     8.000000
# max       4.000000     2.00000    15.000000    10.000000

# %%
# shape of the dataset
df.shape
# Out:
# (1000, 12)

# %%
#  list down the column names
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           8.49             0.378        0.262           10.25      0.119
# 1          15.41             0.913        0.247           12.05      0.163
# 2          12.78             1.409        0.906            4.13      0.154
# 3          11.18             1.198        0.250            9.56      0.039
# 4           5.87             1.310        0.272            8.79      0.038
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   51                   175  0.99517  3.77       1.07
# 1                   71                   172  0.99241  2.91       0.96
# 2                   48                   193  0.99845  3.56       1.97
# 3                   19                   174  1.00416  3.90       0.96
# 4                    6                   294  0.99006  3.05       0.44
#
#    alcohol  quality
# 0    13.48       10
# 1    13.22        1
# 2    12.23        8
# 3    12.80        8
# 4     8.13        2

# %%
df['quality'].unique()
# Out:
# array([10,  1,  8,  2,  7,  3,  0,  4,  9,  5,  6])

# %%
df['quality'].value_counts()
# Out:
# quality
# 2     104
# 4     102
# 9      99
# 1      98
# 3      94
# 0      88
# 6      88
# 5      86
# 8      81
# 7      81
# 10     79
# Name: count, dtype: int64

# %%
#  missing values
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#  check duplicate values
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
#  remove the duplicate records
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.029314     0.014465
# volatile acidity           0.029314          1.000000     0.027271
# citric acid                0.014465          0.027271     1.000000
# residual sugar            -0.029462         -0.005810    -0.013622
# chlorides                  0.034882          0.032845    -0.008858
# free sulfur dioxide       -0.018122         -0.049027    -0.074452
# total sulfur dioxide       0.009080         -0.000731     0.039204
# density                   -0.037679          0.018731     0.004077
# pH                         0.048819         -0.008967    -0.037628
# sulphates                  0.040276          0.006099     0.003126
# alcohol                    0.035760         -0.009795     0.039087
# quality                   -0.024905          0.006610    -0.043401
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity              -0.029462   0.034882            -0.018122
# volatile acidity           -0.005810   0.032845            -0.049027
# citric acid                -0.013622  -0.008858            -0.074452
# residual sugar              1.000000  -0.045079             0.031167
# chlorides                  -0.045079   1.000000            -0.003389
# free sulfur dioxide         0.031167  -0.003389             1.000000
# total sulfur dioxide        0.041301  -0.011972             0.002156
# density                    -0.024359  -0.028112             0.057949
# pH                         -0.033785   0.004111             0.020498
# sulphates                   0.018891  -0.018234             0.045296
# alcohol                     0.044399  -0.014418             0.000313
# quality                     0.069379  -0.009319             0.030081
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                     0.009080 -0.037679  0.048819   0.040276
# volatile acidity                 -0.000731  0.018731 -0.008967   0.006099
# citric acid                       0.039204  0.004077 -0.037628   0.003126
# residual sugar                    0.041301 -0.024359 -0.033785   0.018891
# chlorides                        -0.011972 -0.028112  0.004111  -0.018234
# free sulfur dioxide               0.002156  0.057949  0.020498   0.045296
# total sulfur dioxide              1.000000 -0.042656 -0.014134  -0.023939
# density                          -0.042656  1.000000  0.024030   0.016960
# pH                               -0.014134  0.024030  1.000000  -0.007916
# sulphates                        -0.023939  0.016960 -0.007916   1.000000
# alcohol                           0.032321 -0.036531 -0.007022  -0.034665
# quality                           0.024336  0.013191  0.030055  -0.023443
#
#                        alcohol   quality
# fixed acidity         0.035760 -0.024905
# volatile acidity     -0.009795  0.006610
# citric acid           0.039087 -0.043401
# residual sugar        0.044399  0.069379
# chlorides            -0.014418 -0.009319
# free sulfur dioxide   0.000313  0.030081
# total sulfur dioxide  0.032321  0.024336
# density              -0.036531  0.013191
# pH                   -0.007022  0.030055
# sulphates            -0.034665 -0.023443
# alcohol               1.000000  0.026333
# quality               0.026333  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.quality.value_counts()
# Out:
# quality
# 2     104
# 4     102
# 9      99
# 1      98
# 3      94
# 0      88
# 6      88
# 5      86
# 8      81
# 7      81
# 10     79
# Name: count, dtype: int64

# %%
df.quality.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='quality'>

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           8.49             0.378        0.262           10.25      0.119
# 1          15.41             0.913        0.247           12.05      0.163
# 2          12.78             1.409        0.906            4.13      0.154
# 3          11.18             1.198        0.250            9.56      0.039
# 4           5.87             1.310        0.272            8.79      0.038
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   51                   175  0.99517  3.77       1.07
# 1                   71                   172  0.99241  2.91       0.96
# 2                   48                   193  0.99845  3.56       1.97
# 3                   19                   174  1.00416  3.90       0.96
# 4                    6                   294  0.99006  3.05       0.44
#
#    alcohol  quality
# 0    13.48       10
# 1    13.22        1
# 2    12.23        8
# 3    12.80        8
# 4     8.13        2

# %%
sns.distplot(df['fixed acidity'])
# Out:
# C:\Users\abhay\AppData\Local\Temp\ipykernel_22304\1506967435.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['fixed acidity'])
# <Axes: xlabel='fixed acidity', ylabel='Density'>

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           8.49             0.378        0.262           10.25      0.119
# 1          15.41             0.913        0.247           12.05      0.163
# 2          12.78             1.409        0.906            4.13      0.154
# 3          11.18             1.198        0.250            9.56      0.039
# 4           5.87             1.310        0.272            8.79      0.038
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   51                   175  0.99517  3.77       1.07
# 1                   71                   172  0.99241  2.91       0.96
# 2                   48                   193  0.99845  3.56       1.97
# 3                   19                   174  1.00416  3.90       0.96
# 4                    6                   294  0.99006  3.05       0.44
#
#    alcohol  quality
# 0    13.48       10
# 1    13.22        1
# 2    12.23        8
# 3    12.80        8
# 4     8.13        2

# %%
for i in df.columns:
    sns.histplot(df[i], kde=True)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           8.49             0.378        0.262           10.25      0.119
# 1          15.41             0.913        0.247           12.05      0.163
# 2          12.78             1.409        0.906            4.13      0.154
# 3          11.18             1.198        0.250            9.56      0.039
# 4           5.87             1.310        0.272            8.79      0.038
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   51                   175  0.99517  3.77       1.07
# 1                   71                   172  0.99241  2.91       0.96
# 2                   48                   193  0.99845  3.56       1.97
# 3                   19                   174  1.00416  3.90       0.96
# 4                    6                   294  0.99006  3.05       0.44
#
#    alcohol  quality
# 0    13.48       10
# 1    13.22        1
# 2    12.23        8
# 3    12.80        8
# 4     8.13        2

# %%
# categorical plot
sns.catplot(x='quality', y = 'alcohol', data = df, kind='box')

# %%
sns.scatterplot(x = 'alcohol', y='pH', hue='quality', data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='pH'>
