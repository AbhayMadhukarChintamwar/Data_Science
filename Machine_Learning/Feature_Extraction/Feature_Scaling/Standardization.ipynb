# %% [markdown]
# Feature Extraction in Standardization

# %% [markdown]
# Using manually z-score technique

# %%
import numpy as np
import seaborn as sns

# %%
df =sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(total_bill, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
total_bill = list(df['total_bill'])
total_bill
# Out:
# [16.99,
#  10.34,
#  21.01,
#  23.68,
#  24.59,
#  25.29,
#  8.77,
#  26.88,
#  15.04,
#  14.78,
#  10.27,
#  35.26,
#  15.42,
#  18.43,
#  14.83,
#  21.58,
#  10.33,
#  16.29,
#  16.97,
#  20.65,
#  17.92,
#  20.29,
#  15.77,
#  39.42,
#  19.82,
#  17.81,
#  13.37,
#  12.69,
#  21.7,
#  19.65,
#  9.55,
#  18.35,
#  15.06,
#  20.69,
#  17.78,
#  24.06,
#  16.31,
#  16.93,
#  18.69,
#  31.27,
#  16.04,
#  17.46,
#  13.94,
#  9.68,
#  30.4,
#  18.29,
#  22.23,
#  32.4,
#  28.55,
#  18.04,
#  12.54,
#  10.29,
#  34.81,
#  9.94,
#  25.56,
#  19.49,
#  38.01,
#  26.41,
#  11.24,
#  48.27,
#  20.29,
#  13.81,
#  11.02,
#  18.29,
#  17.59,
#  20.08,
#  16.45,
#  3.07,
#  20.23,
#  15.01,
#  12.02,
#  17.07,
#  26.86,
#  25.28,
#  14.73,
#  10.51,
#  17.92,
#  27.2,
#  22.76,
#  17.29,
#  19.44,
#  16.66,
#  10.07,
#  32.68,
#  15.98,
#  34.83,
#  13.03,
#  18.28,
#  24.71,
#  21.16,
#  28.97,
#  22.49,
#  5.75,
#  16.32,
#  22.75,
#  40.17,
#  27.28,
#  12.03,
#  21.01,
#  12.46,
#  11.35,
# ...

# %%
mean = np.mean(total_bill)
std = np.std(total_bill)

# %%
mean
# Out:
# np.float64(19.78594262295082)

# %%
std
# Out:
# np.float64(8.884150577771132)

# %%
normalized_data = []
for i in total_bill:
    z_score = (i-mean)/std
    normalized_data.append(z_score)

normalized_data
# Out:
# [np.float64(-0.3147113050904943),
#  np.float64(-1.0632353132988692),
#  np.float64(0.13777989987156145),
#  np.float64(0.43831510316725475),
#  np.float64(0.540744704290506),
#  np.float64(0.6195367051545455),
#  np.float64(-1.2399545152367863),
#  np.float64(0.7985071071171495),
#  np.float64(-0.5342033074974614),
#  np.float64(-0.5634689078183903),
#  np.float64(-1.0711145133852733),
#  np.float64(1.7417599174609364),
#  np.float64(-0.49143050702841123),
#  np.float64(-0.15262490331304146),
#  np.float64(-0.557840907756673),
#  np.float64(0.2019391005751361),
#  np.float64(-1.0643609133112126),
#  np.float64(-0.3935033059545337),
#  np.float64(-0.31696250511518104),
#  np.float64(0.09725829942719795),
#  np.float64(-0.2100305039425557),
#  np.float64(0.05673669898283484),
#  np.float64(-0.45203450659639155),
#  np.float64(2.2100095225958003),
#  np.float64(0.003833498402694168),
#  np.float64(-0.2224121040783337),
#  np.float64(-0.7221785095588127),
# ...

# %%
sns.histplot(normalized_data, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# By using Libraries

# %%
from sklearn.preprocessing import StandardScaler

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
scaler = StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
scaler.fit(df[['total_bill','tip']])
# Out:
# StandardScaler()

# %%
import pandas as pd
scalers =pd.DataFrame(scaler.transform(df[['total_bill','tip']]), columns=['total_bill','tip'])

# %%
sns.histplot(scalers['total_bill'], kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>
