# %%
# import seaborn as sns
import matplotlib.pyplot as plt
var = [1,2,3,4,5,6,7]
var1 = [7,6,5,4,3,2,1]
plt.plot(var, var1)
print(plt.show())
# Out:
# Running cells with 'Python 3.14.5' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/abhay/AppData/Roaming/uv/python/cpython-3.14.5-windows-x86_64-none/python.exe -m pip install ipykernel -U --user --force-reinstall'
