# %%
import pandas as pd

# %%
df = pd.read_xml('it_finance_data.xml')

# %%
# Linear Graph

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y=[5,6,7,8]
c = 'r'
plt.plot(x,y,c)
plt.show()

# %%
df = pd.read_xml('it_finance_data.xml')
df
# Out:
#        Employee_ID            Name Department                Role     Company  \
# 0                1      Employee_1         IT   Backend Developer  Microsoft
# 1                2      Employee_2    Finance     DevOps Engineer      Amazon
# 2                3      Employee_3         IT  Frontend Developer         TCS
# 3                4      Employee_4         IT   Software Engineer  Microsoft
# 4                5      Employee_5         IT      Data Scientist   Accenture
# ...            ...             ...        ...                 ...         ...
# 11995        11996  Employee_11996    Finance   Investment Banker  Microsoft
# 11996        11997  Employee_11997    Finance   Investment Banker    Deloitte
# 11997        11998  Employee_11998         IT   Financial Analyst         TCS
# 11998        11999  Employee_11999         IT      Data Scientist       Wipro
# 11999        12000  Employee_12000         IT             Auditor       Wipro
#
#             City   Salary  Experience_Years
# 0         Mumbai  1514341               2.4
# 1           Pune  1495105               8.9
# 2      Hyderabad  1387438              13.9
# 3           Pune  1345806               0.6
# 4           Pune  1962417              10.2
# ...          ...      ...               ...
# 11995      Delhi  1537932               1.0
# 11996      Delhi  1970199               6.9
# 11997  Hyderabad   650399               8.8
# 11998      Delhi  1551349               9.0
# 11999  Bangalore   999198               9.5
#
# [12000 rows x 8 columns]

# %%
x = [1,2,3,4]
y=[5,6,7,8]
c = 'r'
plt.plot(x,y,c)
plt.show()

# %%
x = [1,10,3,14]
y=[15,6,17,8]
c = 'r'
plt.plot(x,y,c)
plt.show()

# %%
# Bar Graph

# %%
import matplotlib.pyplot as plt

# %%
x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
plt.bar(x,y)
plt.show()

# %%
x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
plt.xlabel('Vehicles', fontsize = 15)
plt.ylabel('Numbers of Vehicles',fontsize = 15)
plt.title('Parking survey')
plt.bar(x,y)
plt.show()

# %%
x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.bar(x,y,width = 0.2)
plt.show()

# %%
x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.bar(x,y,width = 0.2, color ='r')
plt.show()

# %%
x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
c = ['red','yellow','green','magenta']
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.bar(x,y,width = 0.2, color = c)
plt.show()

# %%
x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
c = ['red','yellow','green','magenta']
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.bar(x,y,width = 0.2, color = c,align='edge')
plt.show()

# %%
x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
c = ['red','yellow','green','magenta']
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.bar(x,y,width = 0.2, color = c,align='center')
plt.show()

# %%
x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
c = ['red','yellow','green','magenta']
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.bar(x,y,width = 0.2, color = c,align='edge', edgecolor = 'b')
plt.show()

# %%
x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
c = ['red','yellow','green','magenta']
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.bar(x,y,width = 0.2, color = c, edgecolor = 'b', linewidth = 2)
plt.show()

# %%
x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
c = ['red','yellow','green','magenta']
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.bar(x,y,width = 0.2, color = c, edgecolor = 'b', linewidth = 2, linestyle =':')
plt.show()

# %%
x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
c = ['red','yellow','green','magenta']
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.bar(x,y,width = 0.2, color = c, edgecolor = 'b', linewidth = 2, linestyle =':', alpha = 0.4)
plt.show()

# %%
x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
c = ['red','yellow','green','magenta']
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.bar(x,y,width = 0.2, color = c, edgecolor = 'b')
plt.show()

# %%
x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
c = ['red','yellow','green','magenta']
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.bar(x,y,width = 0.2, color = c, edgecolor = 'b')
plt.legend('Transport')
plt.show()

# %%
x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
z = [20,30,40,15]
# c = ['red','yellow','green','magenta']
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.bar(x,y,width = 0.2, color = 'r', edgecolor = 'b')
plt.bar(x,z,width = 0.2, color = 'g', edgecolor = 'b')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
z = [20,30,40,15]
width = 0.2
p  = np.arange(len(x))
p1 = [j+ width for j in p]
# c = ['red','yellow','green','magenta']
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.bar(p,y,width = 0.2, color = 'r', edgecolor = 'b')
plt.bar(p1,z,width = 0.2, color = 'g', edgecolor = 'b')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
z = [20,30,40,15]
width = 0.2
p  = np.arange(len(x))
p1 = [j+ width for j in p]
# c = ['red','yellow','green','magenta']
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.xticks(p +width, x)
plt.bar(p,y,width = 0.2, color = 'r', edgecolor = 'b')
plt.bar(p1,z,width = 0.2, color = 'g', edgecolor = 'b')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
z = [20,30,40,15]
width = 0.2
p  = np.arange(len(x))
p1 = [j+ width for j in p]
# c = ['red','yellow','green','magenta']
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.xticks(p +width/2, x)
plt.bar(p,y,width = 0.2, color = 'r', edgecolor = 'b')
plt.bar(p1,z,width = 0.2, color = 'g', edgecolor = 'b')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
z = [20,30,40,15]
width = 0.2
p  = np.arange(len(x))
p1 = [j+ width for j in p]
# c = ['red','yellow','green','magenta']
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.xticks(p +width/2, x, rotation = 30)
plt.bar(p,y,width = 0.2, color = 'r', edgecolor = 'b')
plt.bar(p1,z,width = 0.2, color = 'g', edgecolor = 'b')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
z = [20,30,40,15]
width = 0.2
p  = np.arange(len(x))
p1 = [j+ width for j in p]
# c = ['red','yellow','green','magenta']
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.xticks(p +width/2, x, rotation = 30)
plt.barh(p,y, color = 'r', edgecolor = 'b')
plt.bar(p1,z, color = 'g', edgecolor = 'b')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ['car', 'bike', 'scooty','bicycle']
y = [40, 85, 75, 35]
z = [20,30,40,15]
width = 0.2
p  = np.arange(len(x))
p1 = [j+ width for j in p]
# c = ['red','yellow','green','magenta']
plt.xlabel('Vehicles')
plt.ylabel('Numbers of Vehicles')
plt.title('Parking survey')
plt.xticks(p +width/2, x, rotation = 30)
plt.barh(p,y, color = 'r', edgecolor = 'b')
plt.barh(p1,z, color = 'g', edgecolor = 'b')

plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
c = ['red','pink','yellow','blue','green','purple']
plt.scatter(x,y, color =c, s= 150)
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
size = [300,170, 350, 264, 209, 219]
c = ['red','pink','yellow','blue','green','purple']
plt.scatter(x,y, color =c, s=size)
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
size = [300,170, 350, 264, 209, 219]
c = ['red', 'pink', 'yellow', 'blue', 'green', 'purple']
plt.scatter(x,y, color =c, s=size,alpha=0.4)
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
size = [300,170, 350, 264, 209, 219]
c = ['red', 'pink', 'yellow', 'blue', 'green', 'purple']
plt.scatter(x,y, color =c, s=size,alpha=0.4,marker ='*')
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
size = [300,170, 350, 264, 209, 219]
c = ['red', 'pink', 'yellow', 'blue', 'green', 'purple']
plt.scatter(x,y, color =c, s=size,alpha=0.4,marker ='*')
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
size = [300,170, 350, 264, 209, 219]
c = ['red', 'pink', 'yellow', 'blue', 'green', 'purple']
plt.scatter(x,y, color =c, s=size,marker ='*', edgecolor = 'brown')
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
size = [300,170, 350, 264, 209, 219]
c = ['red', 'pink', 'yellow', 'blue', 'green', 'purple']
plt.scatter(x,y, color =c, s=size, marker ='*', egdecolor = 'brown', linewidth =2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 13
#      11 size = [300,170, 350, 264, 209, 219]
#      12 c = ['red', 'pink', 'yellow', 'blue', 'green', 'purple']
# ---> 13 plt.scatter(x,y, color =c, s=size, marker ='*', egdecolor = 'brown', linewidth =2)
#      14 plt.show()
#
# File c:\Users\abhay\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\abhay\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:3948, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3928 @_copy_docstring_and_deprecators(Axes.scatter)
#    3929 def scatter(
#    3930     x: float | ArrayLike,
#    (...)   3946     **kwargs,
#    3947 ) -> PathCollection:
# -> 3948     __ret = gca().scatter(
#    3949         x,
#    3950         y,
#    3951         s=s,
#    3952         c=c,
#    3953         marker=marker,
#    3954         cmap=cmap,
#    3955         norm=norm,
#    3956         vmin=vmin,
#    3957         vmax=vmax,
#    3958         alpha=alpha,
#    3959         linewidths=linewidths,
#    3960         edgecolors=edgecolors,
#    3961         colorizer=colorizer,
#    3962         plotnonfinite=plotnonfinite,
#    3963         **({"data": data} if data is not None else {}),
#    3964         **kwargs,
#    3965     )
#    3966     sci(__ret)
#    3967     return __ret
#
# File c:\Users\abhay\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\abhay\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File c:\Users\abhay\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\axes\_axes.py:5055, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    5051         keys_str = ", ".join(f"'{k}'" for k in extra_keys)
#    5052         _api.warn_external(
#    5053             "No data for colormapping provided via 'c'. "
#    5054             f"Parameters {keys_str} will be ignored")
# -> 5055 collection._internal_update(kwargs)
#    5057 # Classic mode only:
#    5058 # ensure there are margins to allow for the
#    5059 # finite size of the symbols.  In v2.x, margins
#    5060 # are present by default, so we disable this
#    5061 # scatter-specific override.
#    5062 if mpl.rcParams['_internal.classic_mode']:
#
# File c:\Users\abhay\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File c:\Users\abhay\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: PathCollection.set() got an unexpected keyword argument 'egdecolor'

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
size = [300,170, 350, 264, 209, 219]
c = ['red', 'pink', 'yellow', 'blue', 'green', 'purple']
plt.scatter(x,y, color =c, s=size,alpha=0.4,marker ='*')
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
size = [300,170, 350, 264, 209, 219]
c = ['red', 'pink', 'yellow', 'blue', 'green', 'purple']
plt.scatter(x,y, color =c, s=size,alpha=0.4,marker ='*', edgecolor = 'brown')
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
size = [300,170, 350, 264, 209, 219]
c = ['red', 'pink', 'yellow', 'blue', 'green', 'purple']
plt.scatter(x,y, color =c, s=size ,marker ='*', edgecolor = 'brown', linewidth = 2)
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
size = [300,170, 350, 264, 209, 219]
c = ['red', 'pink', 'yellow', 'blue', 'green', 'purple']
plt.scatter(x,y, color =c, s=size )
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
size = [300,170, 350, 264, 209, 219]
c = [10,20,30,45,78,99]
plt.scatter(x,y, c = c , s=size , cmap ='Dark2')
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
size = [300,170, 350, 264, 209, 219]
c = [10,20,30,45,78,99]
plt.scatter(x,y, c = c , s=size , cmap ='Dark2')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
size = [300,170, 350, 264, 209, 219]
c = [10,20,30,45,78,99]
plt.scatter(x,y, c = c , s=size , cmap ='winter')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
size = [300,170, 350, 264, 209, 219]
c = [10,20,30,45,78,99]
plt.scatter(x,y, c = c , s=size , cmap ='summer')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
size = [300,170, 350, 264, 209, 219]
c = [10,20,30,45,78,99]
plt.scatter(x,y, c = c , s=size , cmap ='jet')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
size = [300,170, 350, 264, 209, 219]
c = [10,20,30,45,78,99]
plt.scatter(x,y, c = c , s=size , cmap ='jet')
t = plt.colorbar()
t.set_label('Colorbar', fontsize = 15)
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter Plot

x = [1,2,3,4,5,6]
y = [4,2,3,5,1,8]
z = [10,11,12,13,14,15]
plt.title('Scatter Plot', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Number')
# plt.scatter(x,y, color ='r')
size = [300,170, 350, 264, 209, 219]
c = [10,20,30,45,78,99]
plt.scatter(x,y, c = c , s=size , cmap ='jet')
t = plt.colorbar()
t.set_label('Colorbar', fontsize = 15)
plt.scatter(x,z, c = c , s=size , cmap ='Greys')
t = plt.colorbar()
t.set_label('Colorbar', fontsize = 15)
plt.show()
